# %% [markdown]
# # Datathon Fase 5 — Notebook
# # Diego Peres Hatanaka

# %% [markdown]
# ## 1. Setup & Imports

# %%
# %pip -q install scikit-learn==1.5.0 pandas==2.2.2 joblib==1.4.2 scipy==1.13.1
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Normalização dos Dados

# %%
from pathlib import Path
import json, pandas as pd
base = Path("C:/Users/dphat/OneDrive/Documentos/Cursos/FIAP/PosTech_DataAnalytics/fase5/Datathon Decision")
raw = base / "data" / "raw"
# Funções de flatten (simplificadas)
def normalize_text(s): 
    return s or ""
def load_dict(p): 
    import json; 
    return json.load(open(p, "r", encoding="utf-8"))
applicants = load_dict(raw/"applicants.json")
vagas = load_dict(raw/"vagas.json")
# Exibir contagens
print("Applicants:", len(applicants), "Vagas:", len(vagas))
# Out:
# Applicants: 42482 Vagas: 14081

# %% [markdown]
# ## 3. Treino do Pipeline de Similaridade

# %%
from src.train import train
stats = train(base / "data" / "processed", base / "models")
stats
# Out:
# {'vocab_size': 20000}

# %% [markdown]
# ## 4. Exemplo de Ranking para uma Vaga

# %%
import numpy as np
import pandas as pd
from joblib import load
from sklearn.metrics.pairwise import cosine_similarity
from src.utils import normalize_text

# 1) Carregar dados
apps = pd.read_csv(base / "data" / "processed" / "applicants.csv")
vagas = pd.read_csv(base / "data" / "processed" / "vagas.csv")

# 2) Carregar o vetorizador atual do projeto
vec_path = base / "models" / "tfidf_vectorizer.joblib"
vec = load(vec_path)

# (opcional) sanity check
try:
    vocab_size = len(vec.get_feature_names_out())
    print("Vocab size:", vocab_size)
except Exception as e:
    print("Aviso: não consegui ler o vocabulário.", e)

# 3) Selecionar uma vaga
vrow = vagas.iloc[0]

def compute_scores(vec, apps_df, vaga_row, batch=10000):
    # --- montar texto da vaga (1 string) ---
    vaga_text = f"{vaga_row.get('requisitos_texto','')} {vaga_row.get('stack_desejada','')}"
    job_text = [normalize_text(str(vaga_text))]
    B = vec.transform(job_text)  # shape: (1, vocab)

    # --- montar textos dos candidatos (1 por linha) ---
    cv_vals   = apps_df["cv_text_pt"].fillna("").astype(str).values
    stack_vals= apps_df["stack"].fillna("").astype(str).values
    n = len(apps_df)

    scores_parts = []
    for start in range(0, n, batch):
        end = min(n, start + batch)
        # lista de strings normalizadas (um item por candidato)
        app_text_batch = [normalize_text(cv_vals[i] + " " + stack_vals[i]) for i in range(start, end)]
        A = vec.transform(app_text_batch)  # shape: (batch, vocab)
        sims = cosine_similarity(A, B)[:, 0]  # shape: (batch,)
        scores_parts.append(sims)

    scores = np.concatenate(scores_parts, axis=0)
    assert scores.shape[0] == n, f"scores len={scores.shape[0]} != n_apps={n}"
    return scores

scores = compute_scores(vec, apps, vrow, batch=10000)

print("scores shape:", scores.shape, "| n_apps:", len(apps))
out = apps.assign(match_score=scores).sort_values("match_score", ascending=False).head(20)
out
# Out:
# Vocab size: 20000
# scores shape: (42482,) | n_apps: 42482
#        applicant_id                    nome  senioridade  area_atuacao  \
# 21462         27124        Eduardo Caldeira          NaN           NaN
# 41381         37788      Sra. Letícia Ramos          NaN           NaN
# 30308         29441       Leonardo Carvalho          NaN           NaN
# 24100         20009             Bento Pinto          NaN           NaN
# 41003         40186           Bárbara Gomes          NaN           NaN
# 37426         36176  Srta. Liz da Conceição          NaN           NaN
# 37348         36098      Danilo Casa Grande          NaN           NaN
# 26157         39112          Dr. Ravi Jesus          NaN           NaN
# 39709         41394      João Vitor Pereira          NaN           NaN
# 16905         46417    Srta. Allana Marques          NaN           NaN
# 31978         15561     Srta. Zoe das Neves          NaN           NaN
# 10595         38806            Maysa Araújo          NaN           NaN
# 30867         26000     Dr. Guilherme Souza          NaN           NaN
# 27650          7303        Alexandre Mendes          NaN           NaN
# 41802         43270      Dr. Bruno Mendonça          NaN           NaN
# 7006          40794    Dr. José Miguel Dias          NaN           NaN
# 8099          30201  Maria Vitória Teixeira          NaN           NaN
# 26804         21457             Laís da Paz          NaN           NaN
# 23084         43365      Maria Eduarda Lima          NaN           NaN
# 21475         27137          Rafael da Mata          NaN           NaN
#
#        pretensao_salarial  localidade  stack  idiomas  \
# 21462                 NaN         NaN    NaN      NaN
# 41381                 NaN         NaN    NaN      NaN
# 30308                 NaN         NaN    NaN      NaN
# 24100                 NaN         NaN    NaN      NaN
# 41003                 NaN         NaN    NaN      NaN
# 37426                 NaN         NaN    NaN      NaN
# 37348                 NaN         NaN    NaN      NaN
# 26157                 NaN         NaN    NaN      NaN
# 39709                 NaN         NaN    NaN      NaN
# 16905                 NaN         NaN    NaN      NaN
# 31978                 NaN         NaN    NaN      NaN
# 10595                 NaN         NaN    NaN      NaN
# 30867                 NaN         NaN    NaN      NaN
# 27650                 NaN         NaN    NaN      NaN
# 41802                 NaN         NaN    NaN      NaN
# 7006                  NaN         NaN    NaN      NaN
# 8099                  NaN         NaN    NaN      NaN
# 26804                 NaN         NaN    NaN      NaN
# 23084                 NaN         NaN    NaN      NaN
# 21475                 NaN         NaN    NaN      NaN
#
#                                               cv_text_pt  cv_text_en  \
# 21462  service delivery management for infraestructur...         NaN
# 41381     \n\n\ncontato\n\nprincipais competências re...         NaN
# 30308  incident manager\n\nsummary of skills and prof...         NaN
# 24100  sr it manager / mba\naddress são paulo, sp, 04...         NaN
# 41003  \n\n\n\n● professional with 18 years of experi...         NaN
# 37426  42 years old – uberlandia – brazil\n\ncover le...         NaN
# 37348  isaque melo (71) 98110 - 6579 brazilian, divor...         NaN
# 26157  single, 34 y/o, available to travel;\n\n\ninte...         NaN
# 39709  +55 11 99263 1457\n\nbpo director, digital ope...         NaN
# 16905  citizenship: brazilian and italian\nmobile/ wh...         NaN
# 31978  estava na tango como arquiteto de logística, f...         NaN
# 10595  enterprise cloud architect\nsão paulo, são pau...         NaN
# 30867  \n\n\nobjective\nproject manager/ti or service...         NaN
# 27650     \n\n\ncontact\nit | delivery manager sap | ...         NaN
# 41802  \n\n\n\nit business analyst | product owner | ...         NaN
# 7006   são caetano do sul - sp\n\nobjetive\n\n\nactin...         NaN
# 8099   marília/sp\ntem empresa me, só atende como pj\...         NaN
# 26804  elisangela morita\n\n\nprofile\nof requirement...         NaN
# 23084  consultant sênior sap - financial services\n\n...         NaN
# 21475  page\n\n\n\n\n\nobjective: delivery manager\n\...         NaN
#
#        cargo_atual  match_score
# 21462          NaN     0.451839
# 41381          NaN     0.443031
# 30308          NaN     0.441924
# 24100          NaN     0.427060
# 41003          NaN     0.426514
# 37426          NaN     0.416064
# 37348          NaN     0.415494
# 26157          NaN     0.413141
# 39709          NaN     0.409767
# 16905          NaN     0.409241
# 31978          NaN     0.407022
# 10595          NaN     0.406062
# 30867          NaN     0.402344
# 27650          NaN     0.401625
# 41802          NaN     0.400992
# 7006           NaN     0.400797
# 8099           NaN     0.391266
# 26804          NaN     0.390065
# 23084          NaN     0.389654
# 21475          NaN     0.388971
